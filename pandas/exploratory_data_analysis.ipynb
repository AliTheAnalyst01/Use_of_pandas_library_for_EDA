# %% [markdown]
# # EDA of Titanic data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 2.bigger picture of data

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# for the percentage of null value
df2.isnull().sum() * 100/len(df2)
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
# if any colunm have the null value above than 70% of that column than it waste

# %%
df2=df

# %%
df2['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df2['age'].max()
# Out:
# 80.0

# %%
 df2['age'].fillna(df2['age'].mean(),inplace=True)

# %%
df2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df3 = df2

# %%
df3.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df3=df3.drop(columns='deck')

# %%
df3.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df4 = df3

# %%
df4['embark_town'].fillna(df4['embark_town'].mode()[0],inplace=True)

# %%
df4.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df4['embarked'].fillna(df4['embarked'].mode()[0],inplace=True)

# %%
df4.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# visulize nan value in heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.drop(columns='deck',inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# visulize and explore
sns.countplot(data=df,x='survived') # countplot mey yaxis par xaxis ki counting ati hey na k variable
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.barplot(data=df,x='survived',y='age',hue='who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.countplot(data=df,x='pclass')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
# data distribution
sns.histplot(data=df,x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',bins=10)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data=df,x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# box plot banatey waqt hum ney aik side pay numerical value lena hey or dosri side par categorical
sns.boxplot(data=df,y='age')
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.boxplot(data=df,y='age',x = 'survived')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=df,y='age',x = 'who')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.boxplot(data=df,y='age',x = 'survived',hue='who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.scatterplot(data=df,x='age',y='fare')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=df,x='age',y='fare',hue='pclass')
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
sns.pairplot(df,hue='survived')

# %%
# stacked barchart or plot
df.groupby(['pclass','sex'])['survived'].mean().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
# stacked barchart or plot
df.groupby(['pclass','who'])['survived'].mean().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
# stacked barchart or plot
df.groupby(['pclass','sex'])['fare'].mean().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
sns.swarmplot(data=df,x='age',y='fare')
# Out:
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=df,x='survived',y='fare')
# Out:
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 63.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 32.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='fare'>
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 72.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=df,x='survived',y='age')
# Out:
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='age'>
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 29.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=df,x='survived',y='age',hue='who')
# Out:
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='age'>
# c:\Users\ANZAR AZIZ\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 29.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(data=df,x='class',y='fare',hue='embarked',kind='point')

# %%
# to check the relation of two numerical value
sns.lmplot(data=df,x='age',y='fare')

# %%
sns.lmplot(data=df,x='age',y='fare',hue='who')

# %%
# how to add a column in a age grouop
df['age_group'] = pd.cut(df['age'],[0,10,18,30,50,80],
                         labels=['kids','child','youth','middle age','old'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone   age_group
# 0    man        True  Southampton    no  False       youth
# 1  woman       False    Cherbourg   yes  False  middle age
# 2  woman       False  Southampton   yes   True       youth
# 3  woman       False  Southampton   yes  False  middle age
# 4    man        True  Southampton    no   True  middle age

# %%
df.groupby(['age_group','who'])['survived'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age_group,who'>

# %%
sns.pairplot(df,hue='survived',vars=['age','fare','pclass'])

# %%
df['family_size'] = df['sibsp'] + df['parch']

# %%
df.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0         0       3    male  22.000000      1      0   7.2500        S
# 1         1       1  female  38.000000      1      0  71.2833        C
# 2         1       3  female  26.000000      0      0   7.9250        S
# 3         1       1  female  35.000000      1      0  53.1000        S
# 4         0       3    male  35.000000      0      0   8.0500        S
# 5         0       3    male  29.699118      0      0   8.4583        Q
# 6         0       1    male  54.000000      0      0  51.8625        S
# 7         0       3    male   2.000000      3      1  21.0750        S
# 8         1       3  female  27.000000      0      2  11.1333        S
# 9         1       2  female  14.000000      1      0  30.0708        C
#
#     class    who  adult_male  embark_town alive  alone   age_group  \
# 0   Third    man        True  Southampton    no  False       youth
# ...
